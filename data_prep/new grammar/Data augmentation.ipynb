# %% [markdown]
# # Data augmentation
#
# ## 1 Current data statistics
#
# ### We read in the files of queries, logical forms, and schema, and categorize them by length; within the same length, there would be subcategories

# %%
import numpy as np

logic_category_len = dict()
query_len = dict()
schema_len = dict()
with open('./rand.lo') as f_lo:
    with open('./rand.qu') as f_qu:
        with open('./rand.fi') as f_fi:
            logic_line, query_line, schema_line = f_lo.readline(), f_qu.readline(), f_fi.readline()
            while logic_line and query_line and schema_line:
                logic = logic_line.split()
                if len(logic) == 13:
                    if logic[4] == 'less':
                        logic[0] = 'argmax'
                    else:
                        logic[0] = 'argmin'
                    logic.insert(2, logic[3])
                length = len(logic)
                if length not in logic_category_len:
                    logic_category_len[length] = []
                    query_len[length] = []
                    schema_len[length] = []
                logic_category_len[length].append(logic_line)
                query_len[length].append(query_line)
                schema_len[length].append(schema_line)
                logic_line, query_line, schema_line = f_lo.readline(), f_qu.readline(), f_fi.readline()
for key in logic_category_len.keys():
    value = logic_category_len[key]
    print 'length = %d, total examples: %d' %(key, len(value))
# Out:
# length = 2, total examples: 2
# length = 3, total examples: 156
# length = 5, total examples: 128
# length = 6, total examples: 1047
# length = 7, total examples: 624
# length = 10, total examples: 687
# length = 11, total examples: 487
# length = 12, total examples: 4
# length = 14, total examples: 157
# length = 18, total examples: 618

# %% [markdown]
# Have a look at the data:

# %%
for i in range(len(logic_category_len[7])):
    print query_len[7][i]
    #print logic_category_len[14][i]
# Out:
# who has the least apps and greater than 22 goals
#
# which year was the latest year that havana was the 2nd_venue
#
# who has the most field_goals with an average of 50
#
# which year was the most recent year cambridge was the 2nd_venue
#
# who has the least apps and greater than 114 goals
#
# which year was the latest year that boston was the 2nd_venue
#
# when was the first time nassau was 2nd_venue
#
# what is the amount of the most goals before 2000
#
# who has the least runs with an average above 20
#
# who has the most goals but less than 268 apps
#
# when was the first time detroit was 2nd_venue
#
# who has the least matches with an average above 70
#
# who has the most free_throws with an average above 30
#
# who has the least goals and less than 253 apps
#
# what is the amount of the least goals before 2016
#
# what is the amount of the least goals before 2014
#
# which state had the least number_of_candidates in 2015
#
# what is the amount of the least goals after 2001
#
# who has the most innings with an average of 80
#
# what is the amount of the least goals after 2005
#
# who has the most runs with an average above 50
#
# who has the most points with an average above 20
#
# who has the most innings with an average above 30
#
# who has the least 100s with an average below 30
#
# who has the most games played with an average above 80
#
# when was the first time hangzhou was 3rd_venue
#
# who has the least apps and greater than 166 goals
#
# who has the most free_throws with an average of 50
#
# when was the first time veracruz was 3rd_venue
#
# what is the amount of the most goals before 2003
#
# who has the most innings with an average above 80
#
# which year was the latest year that hangzhou was the 1st_venue
#
# who has the least runs with an average below 80
#
# what is the amount of the most goals before 2006
#
# who has the most matches with an average below 80
#
# who has the most goals but less than 324 apps
#
# which year was the latest year that tokyo was the 2nd_venue
#
# which state had the least number_of_candidates in 1999
#
# what is the amount of the least goals after 1997
#
# who has the most goals but less than 325 apps
#
# what is the amount of the least goals before 2001
#
# who has the most field_goals with an average of 30
#
# who has the least field_goals with an average of 70
#
# who has the least apps and less than 57 goals
#
# what is the amount of the most goals after 1998
#
# who has the least matches with an average of 20
#
# which year was the most recent year hangzhou was the 2nd_venue
#
# what is the amount of the least goals after 2008
#
# who has the least points with an average of 80
#
# who has the most matches with an average of 80
#
# who has the least 50s with an average below 20
#
# which year was the latest year that indianapolis was the 2nd_venue
#
# who has the most 50s with an average below 20
#
# which year was the latest year that sydney was the 1st_venue
#
# who is the defender with the least goals
#
# who has the most runs with an average of 30
#
# who has the least runs with an average above 70
#
# who has the least points with an average above 30
#
# who has the least free_throws with an average below 70
#
# who has the least free_throws with an average above 50
#
# what is the amount of the most goals after 1997
#
# who has the most innings with an average of 70
#
# what is the amount of the most goals after 2013
#
# when was the first time austin was 3rd_venue
#
# who has the least matches with an average above 80
#
# who has the least apps and less than 101 goals
#
# what is the amount of the most goals after 2012
#
# who has the least goals and less than 352 apps
#
# who has the most points with an average above 70
#
# what is the amount of the least goals before 2008
#
# who has the least games played with an average of 50
#
# what is the amount of the least goals before 2010
#
# when was the first time mexico_city was 2nd_venue
#
# who has the most free_throws with an average of 30
#
# who has the least innings with an average above 30
#
# who is the forward with the least goals
#
# which year was the latest year that seattle was the 1st_venue
#
# who has the least apps and less than 156 goals
#
# what is the amount of the most goals after 2015
#
# who has the least apps and less than 140 goals
#
# who has the least goals and less than 215 apps
#
# who has the least points with an average below 70
#
# when was the first time beijing was 2nd_venue
#
# which year was the most recent year sheffield was the 2nd_venue
#
# who has the least matches with an average of 80
#
# who has the least apps and less than 170 goals
#
# who has the most runs with an average below 30
#
# when was the first time guanajuato was 3rd_venue
#
# what is the amount of the most goals before 1999
#
# which state had the least number_of_candidates in 2009
#
# who has the most points with an average below 30
#
# who is the goalkeeper with the least apps
#
# who is the midfielder with the least apps
#
# who has the least apps and less than 172 goals
#
# who has the most points with an average of 30
#
# which year was the latest year that dubai was the 1st_venue
#
# who has the least innings with an average below 80
#
# who has the most runs with an average below 80
#
# who has the least apps and greater than 132 goals
#
# which state had the least number_of_candidates in 1995
#
# who has the most 100s with an average below 70
#
# when did the last to take_office who was respect
#
# who has the least points with an average of 50
#
# which year was the latest year that chicago was the 2nd_venue
#
# who has the most 50s with an average above 20
#
# when was the first time sydney was 2nd_venue
#
# which year was the latest year that guanajuato was the 1st_venue
#
# who has the least goals and less than 66 apps
#
# who has the least 50s with an average below 80
#
# who has the most runs with an average of 70
#
# who has the least points with an average above 70
#
# who has the most games played with an average above 70
#
# which state had the least number_of_candidates in 2011
#
# when was the first time changzhou was 2nd_venue
#
# who has the least free_throws with an average of 80
#
# who has the least runs with an average of 30
#
# who has the most innings with an average of 50
#
# who has the least 50s with an average of 20
#
# when was the first time chicago was 2nd_venue
#
# who has the most free_throws with an average above 70
#
# which state had the least number_of_candidates in 1997
#
# who has the most runs with an average of 50
#
# when was the first time guanajuato was 2nd_venue
#
# who has the least points with an average of 70
#
# who has the least field_goals with an average above 50
#
# who has the most 100s with an average below 30
#
# who has the most field_goals with an average of 80
#
# who has the most games played with an average of 80
#
# which state had the least number_of_candidates in 1996
#
# who has the most runs with an average above 80
#
# what is the amount of the most goals before 1998
#
# when was the first time hangzhou was 2nd_venue
#
# when did the first to take_office who was respect
#
# which year was the latest year that shanghai was the 1st_venue
#
# who has the most runs with an average below 50
#
# who has the least apps and greater than 89 goals
#
# when was the first time nanjing was 2nd_venue
#
# when was the first time seattle was 2nd_venue
#
# who is the forward with the least apps
#
# who has the least runs with an average of 20
#
# what is the amount of the most goals before 2007
#
# who has the most innings with an average below 30
#
# when did the first to take_office who was socialist_alternative
#
# when did the last to leave_office who was independent
#
# when was the first time tokyo was 2nd_venue
#
# who has the most free_throws with an average of 20
#
# what is the amount of the most goals after 2002
#
# who has the least matches with an average above 30
#
# when was the first time sheffield was 2nd_venue
#
# who has the least field_goals with an average of 80
#
# who is the midfielder with the most apps
#
# who has the least goals and less than 476 apps
#
# who has the least points with an average above 80
#
# which year was the most recent year mexico_city was the 2nd_venue
#
# who has the most points with an average below 50
#
# who has the most points with an average of 20
#
# what is the amount of the least goals after 1998
#
# which year was the latest year that mexico_city was the 2nd_venue
#
# when did the first to take_office who was british_national_party
#
# who has the least field_goals with an average of 50
#
# when did the first to leave_office who was green
#
# who has the most points with an average above 30
#
# who has the most games played with an average of 30
#
# who has the most 100s with an average of 20
#
# when did the last to take_office who was labour
#
# what is the amount of the most goals before 1996
#
# who has the least free_throws with an average above 80
#
# who has the most games played with an average of 20
#
# when did the first to take_office who was no_party
#
# what is the amount of the most goals before 2005
#
# which year was the latest year that sydney was the 2nd_venue
#
# which year was the latest year that los_angeles was the 1st_venue
#
# what is the amount of the least goals before 2011
#
# who has the most games played with an average below 30
#
# what is the amount of the least goals before 2000
#
# which year was the latest year that veracruz was the 1st_venue
#
# who has the least apps and greater than 46 goals
#
# who has the least apps and greater than 71 goals
#
# who has the most field_goals with an average above 30
#
# when was the first time doha was 3rd_venue
#
# who has the least free throws with an average of 30
#
# which year was the latest year that cambridge was the 1st_venue
#
# who has the least points with an average below 80
#
# when was the first time shanghai was 2nd_venue
#
# who has the least games played with an average of 80
#
# who has the least 50s with an average below 30
#
# who has the most innings with an average above 20
#
# who has the least games played with an average below 80
#
# who has the least apps and greater than 23 goals
#
# what is the amount of the least goals after 2006
#
# which year was the most recent year dubai was the 2nd_venue
#
# who has the least matches with an average below 50
#
# who has the least innings with an average below 30
#
# what is the amount of the most goals after 2011
#
# when was the first time beijing was 3rd_venue
#
# who has the least free_throws with an average above 20
#
# when was the first time washington was 3rd_venue
#
# when was the first time cambridge was 3rd_venue
#
# when was the first time cambridge was 2nd_venue
#
# who has the least free_throws with an average below 30
#
# what is the amount of the most goals after 2007
#
# who has the most 50s with an average above 80
#
# which year was the latest year that caracas was the 2nd_venue
#
# when did the first to take_office who was green
#
# who has the least free_throws with an average of 50
#
# who is the defender with the most apps
#
# who has the most games played with an average below 80
#
# who has the most matches with an average above 50
#
# when did the first to leave_office who was no_party
#
# which year was the most recent year indianapolis was the 2nd_venue
#
# which state had the least number_of_candidates in 2007
#
# when was the first time mexico_city was 3rd_venue
#
# who has the most points with an average below 20
#
# when did the first to leave_office who was liberal_democrats
#
# what is the amount of the least goals before 2015
#
# who has the least field_goals with an average above 80
#
# who has the most field_goals with an average below 50
#
# who has the least 100s with an average above 50
#
# who has the least innings with an average of 80
#
# who has the most 50s with an average below 50
#
# what is the amount of the most goals before 2016
#
# who has the least 100s with an average of 30
#
# when did the first to take_office who was independent
#
# who has the least points with an average of 20
#
# who has the least 50s with an average above 80
#
# who has the least runs with an average below 20
#
# when was the first time havana was 3rd_venue
#
# who has the most runs with an average above 20
#
# which year was the latest year that changzhou was the 1st_venue
#
# what is the amount of the least goals after 2002
#
# which year was the latest year that changzhou was the 2nd_venue
#
# what is the amount of the least goals after 2010
#
# when did the last to leave_office who was no_party
#
# who has the least matches with an average of 50
#
# who has the least games played with an average of 70
#
# who has the most 100s with an average of 70
#
# which year was the most recent year guanajuato was the 2nd_venue
#
# which year was the most recent year beijing was the 2nd_venue
#
# what is the amount of the least goals after 2014
#
# when was the first time nanjing was 3rd_venue
#
# when was the first time havana was 2nd_venue
#
# what is the amount of the least goals after 2004
#
# what is the amount of the most goals before 2011
#
# who has the least goals and less than 388 apps
#
# who has the most goals but less than 334 apps
#
# who has the most 100s with an average above 50
#
# when was the first time indianapolis was 3rd_venue
#
# when did the last to leave_office who was respect
#
# when did the last to take_office who was green
#
# who has the least innings with an average of 30
#
# what is the amount of the least goals before 1996
#
# when did the last to leave_office who was labour
#
# who has the most 50s with an average above 30
#
# who has the most 100s with an average of 30
#
# who has the least points with an average below 30
#
# who has the most innings with an average above 70
#
# who has the most 100s with an average above 80
#
# who is the defender with the least apps
#
# when was the first time washington was 2nd_venue
#
# who has the least field_goals with an average below 80
#
# who has the least apps and greater than 107 goals
#
# what is the amount of the least goals after 1996
#
# what is the amount of the least goals before 1997
#
# when was the first time doha was 2nd_venue
#
# what is the amount of the least goals before 1999
#
# when was the first time tokyo was 3rd_venue
#
# who has the most 50s with an average above 70
#
# what is the amount of the least goals after 2015
#
# who has the least apps and greater than 138 goals
#
# who has the least apps and less than 101 goals
#
# when was the first time indianapolis was 2nd_venue
#
# what is the amount of the least goals after 2016
#
# which year was the latest year that austin was the 1st_venue
#
# what is the amount of the least goals after 2007
#
# who has the least apps and less than 123 goals
#
# when did the first to leave_office who was conservatives
#
# who has the least innings with an average below 20
#
# who has the most games played with an average below 20
#
# who has the most runs with an average of 20
#
# which state had the least number_of_candidates in 1998
#
# what is the amount of the least goals before 2006
#
# when did the first to leave_office who was british_national_party
#
# who has the most runs with an average above 70
#
# which year was the latest year that beijing was the 2nd_venue
#
# who has the least 100s with an average of 80
#
# what is the amount of the most goals after 1996
#
# who has the most free_throws with an average of 70
#
# who has the least apps and greater than 165 goals
#
# which state had the least number_of_candidates in 2002
#
# who has the least 50s with an average above 50
#
# what is the amount of the least goals before 1998
#
# who has the least games played with an average of 30
#
# when did the last to leave_office who was british_national_party
#
# who has the least goals and less than 113 apps
#
# who has the least apps and greater than 131 goals
#
# who has the least games played with an average above 70
#
# what is the amount of the most goals before 2013
#
# what is the amount of the most goals after 2005
#
# who has the least goals and less than 203 apps
#
# who has the most goals but less than 139 apps
#
# who has the least points with an average above 20
#
# who has the least matches with an average below 30
#
# what is the amount of the most goals before 2004
#
# who has the most field_goals with an average below 70
#
# which year was the most recent year boston was the 2nd_venue
#
# when did the last to take_office who was no_party
#
# who has the most innings with an average below 50
#
# who has the least field_goals with an average below 70
#
# which year was the latest year that dubai was the 2nd_venue
#
# who has the most 50s with an average below 70
#
# what is the amount of the most goals after 2014
#
# who has the most 100s with an average below 80
#
# who has the least 100s with an average above 70
#
# which year was the latest year that mexico_city was the 1st_venue
#
# who has the least games played with an average below 70
#
# who has the least goals and less than 123 apps
#
# what is the amount of the most goals before 2008
#
# who has the least goals and less than 99 apps
#
# who has the least games played with an average above 50
#
# what is the amount of the least goals after 2009
#
# who is the midfielder with the least goals
#
# which state had the least number_of_candidates in 2000
#
# what is the amount of the least goals after 2013
#
# when was the first time sydney was 3rd_venue
#
# who has the least runs with an average above 50
#
# who has the least 50s with an average of 50
#
# which year was the latest year that boston was the 1st_venue
#
# who has the most games played with an average of 70
#
# which year was the most recent year caracas was the 2nd_venue
#
# who has the least goals and less than 494 apps
#
# who has the most free_throws with an average of 80
#
# who has the least games played with an average below 20
#
# who has the most goals but less than 494 apps
#
# who is the goalkeeper with the least goals
#
# who has the most free throws with an average above 80
#
# who has the most points with an average below 70
#
# when did the last to leave_office who was socialist_alternative
#
# who has the most free_throws with an average below 50
#
# who has the most runs with an average below 70
#
# who has the least field_goals with an average above 20
#
# who has the least points with an average below 50
#
# who has the most runs with an average above 30
#
# who has the least apps and greater than 142 goals
#
# who has the least 100s with an average above 80
#
# who has the least innings with an average above 20
#
# who has the least 50s with an average below 70
#
# which year was the most recent year shanghai was the 2nd_venue
#
# who has the least field_goals with an average of 20
#
# who has the most field_goals with an average above 50
#
# what is the amount of the least goals before 2005
#
# when did the first to leave_office who was socialist_alternative
#
# when did the first to leave_office who was independent
#
# what is the amount of the least goals before 2013
#
# who has the least apps and greater than 158 goals
#
# who has the most points with an average above 80
#
# when was the first time dubai was 2nd_venue
#
# what is the amount of the most goals before 2001
#
# who has the least apps and greater than 66 goals
#
# who has the most goals but less than 494 apps
#
# who has the least apps and greater than 199 goals
#
# which year was the most recent year austin was the 2nd_venue
#
# who has the most goals but less than 301 apps
#
# who has the most games played with an average below 70
#
# who has the most runs with an average below 20
#
# who has the least apps and less than 148 goals
#
# which state had the least number_of_candidates in 2006
#
# who has the least 50s with an average above 70
#
# what is the amount of the least goals before 2009
#
# who has the least matches with an average below 20
#
# which year was the most recent year sydney was the 2nd_venue
#
# who has the most 100s with an average above 20
#
# when was the first time los_angeles was 2nd_venue
#
# who has the most matches with an average of 20
#
# which year was the latest year that los_angeles was the 2nd_venue
#
# what is the amount of the least goals before 2007
#
# who has the most goals but less than 215 apps
#
# what is the amount of the most goals before 2009
#
# which year was the most recent year seattle was the 2nd_venue
#
# who has the least innings with an average above 70
#
# who has the most free_throws with an average above 20
#
# who has the least innings with an average above 50
#
# when was the first time minneapolis was 3rd_venue
#
# who has the most field_goals with an average above 80
#
# who has the least field_goals with an average below 20
#
# what is the amount of the least goals before 2003
#
# who has the least runs with an average above 30
#
# who has the least free_throws with an average above 70
#
# who has the least runs with an average below 50
#
# who has the most games played with an average of 50
#
# when was the first time austin was 2nd_venue
#
# when did the first to take_office who was liberal_democrats
#
# which year was the most recent year washington was the 2nd_venue
#
# which year was the most recent year nassau was the 2nd_venue
#
# who has the least goals and less than 300 apps
#
# when did the first to leave_office who was respect
#
# which year was the latest year that shanghai was the 2nd_venue
#
# who has the most 100s with an average above 70
#
# who has the least points with an average below 20
#
# who has the least 50s with an average of 30
#
# who has the most games played with an average above 20
#
# who has the most field_goals with an average above 70
#
# who has the least innings with an average of 70
#
# who has the least runs with an average of 80
#
# who has the least matches with an average below 70
#
# who has the most 50s with an average above 50
#
# what is the amount of the most goals before 2014
#
# who is the forward with the most apps
#
# who has the least runs with an average of 70
#
# which state had the least number_of_candidates in 2005
#
# who has the least goals and less than 97 apps
#
# which year was the latest year that austin was the 2nd_venue
#
# who has the most goals but less than 285 apps
#
# which year was the latest year that nassau was the 1st_venue
#
# who has the most matches with an average of 30
#
# who has the least field_goals with an average above 30
#
# who has the most field_goals with an average below 20
#
# who has the least apps and less than 55 goals
#
# who has the least apps and less than 187 goals
#
# who has the least 50s with an average above 30
#
# when did the last to take_office who was socialist_alternative
#
# who has the least matches with an average of 30
#
# which year was the latest year that veracruz was the 2nd_venue
#
# who has the least 100s with an average below 70
#
# which state had the least number_of_candidates in 2001
#
# who has the least goals and less than 424 apps
#
# what is the amount of the most goals after 2001
#
# which year was the latest year that hangzhou was the 2nd_venue
#
# what is the amount of the least goals after 2003
#
# which year was the latest year that caracas was the 1st_venue
#
# who has the least apps and less than 36 goals
#
# who has the most runs with an average of 80
#
# when did the last to take_office who was conservatives
#
# who has the most free_throws with an average above 50
#
# who has the least apps and less than 90 goals
#
# who has the most 50s with an average of 50
#
# who has the most 50s with an average below 80
#
# who has the least 100s with an average of 70
#
# which year was the most recent year changzhou was the 2nd_venue
#
# who has the least runs with an average below 30
#
# who has the least free_throws with an average of 70
#
# who has the most matches with an average of 70
#
# who has the most field_goals with an average below 80
#
# which year was the latest year that beijing was the 1st_venue
#
# who has the least 100s with an average above 20
#
# when was the first time caracas was 2nd_venue
#
# what is the amount of the least goals before 2012
#
# who has the most 100s with an average of 80
#
# when was the first time veracruz was 2nd_venue
#
# what is the amount of the most goals after 2000
#
# who has the least 50s with an average above 20
#
# when was the first time dubai was 3rd_venue
#
# who has the most innings with an average below 20
#
# when was the first time san_jose was 3rd_venue
#
# who has the most matches with an average of 50
#
# when was the first time san_jose was 2nd_venue
#
# what is the amount of the most goals before 2002
#
# who has the least free_throws with an average below 50
#
# who has the least apps and less than 29 goals
#
# what is the amount of the least goals after 2000
#
# who has the most matches with an average below 20
#
# who has the least apps and less than 4 goals
#
# who has the least goals and less than 415 apps
#
# what is the amount of the most goals before 1997
#
# which year was the latest year that havana was the 1st_venue
#
# who has the most 100s with an average above 30
#
# which state had the least number_of_candidates in 2008
#
# what is the amount of the least goals before 2004
#
# who has the least innings with an average of 20
#
# when was the first time nassau was 3rd_venue
#
# who has the most field_goals with an average below 30
#
# which year was the latest year that nassau was the 2nd_venue
#
# who has the least goals and less than 362 apps
#
# who has the least 50s with an average of 80
#
# who has the most matches with an average below 30
#
# who has the least matches with an average above 20
#
# when was the first time boston was 2nd_venue
#
# when did the last to take_office who was british_national_party
#
# when was the first time detroit was 3rd_venue
#
# who has the most 50s with an average of 70
#
# who has the most points with an average of 50
#
# who has the most goals but less than 176 apps
#
# when was the first time chicago was 3rd_venue
#
# who has the least runs with an average below 70
#
# who has the least games played with an average above 20
#
# who has the most games played with an average below 50
#
# who has the least goals and less than 171 apps
#
# who has the least field_goals with an average of 30
#
# when was the first time caracas was 3rd_venue
#
# who has the least apps and greater than 79 goals
#
# who has the least innings with an average below 70
#
# who has the least 50s with an average below 50
#
# when was the first time changzhou was 3rd_venue
#
# who has the most innings with an average below 70
#
# who has the least matches with an average of 70
#
# who has the most innings with an average of 20
#
# who has the least free_throws with an average below 20
#
# who has the most points with an average of 80
#
# which year was the most recent year havana was the 2nd_venue
#
# who has the most 50s with an average of 30
#
# which state had the least number_of_candidates in 2004
#
# who has the least free_throws with an average of 20
#
# who has the least 100s with an average below 50
#
# when was the first time los_angeles was 3rd_venue
#
# who has the most matches with an average above 70
#
# when did the first to take_office who was conservatives
#
# who has the most goals but less than 250 apps
#
# who has the least apps and less than 152 goals
#
# when did the last to take_office who was independent
#
# who has the most matches with an average below 50
#
# who has the least innings with an average below 50
#
# who has the least 100s with an average below 80
#
# which year was the latest year that sheffield was the 1st_venue
#
# what is the amount of the least goals before 2002
#
# who has the least 100s with an average of 20
#
# who has the most field_goals with an average of 70
#
# who has the least apps and less than 132 goals
#
# who has the least runs with an average above 80
#
# what is the amount of the most goals before 2012
#
# who has the least points with an average of 30
#
# who has the most free throws with an average below 70
#
# when was the first time shanghai was 3rd_venue
#
# who has the least games played with an average above 80
#
# which year was the latest year that seattle was the 2nd_venue
#
# who has the most goals but less than 312 apps
#
# who has the most goals but less than 225 apps
#
# which year was the latest year that washington was the 2nd_venue
#
# which state had the least number_of_candidates in 2010
#
# who has the least apps and less than 28 goals
#
# who has the most goals but less than 409 apps
#
# what is the amount of the most goals after 2006
#
# who has the least points with an average above 50
#
# who has the most 100s with an average of 50
#
# what is the amount of the least goals after 2011
#
# what is the amount of the most goals after 2004
#
# when did the first to take_office who was labour
#
# when was the first time seattle was 3rd_venue
#
# who has the least apps and greater than 27 goals
#
# who has the most goals but less than 326 apps
#
# which state had the least number_of_candidates in 2012
#
# who has the least games played with an average above 30
#
# who has the least goals and less than 295 apps
#
# when did the last to leave_office who was green
#
# who has the most goals but less than 339 apps
#
# who has the most innings with an average below 80
#
# who has the least goals and less than 115 apps
#
# who has the least goals and less than 363 apps
#
# what is the amount of the least goals after 1999
#
# who has the least 100s with an average above 30
#
# when did the last to leave_office who was liberal_democrats
#
# who has the most 100s with an average below 50
#
# what is the amount of the most goals before 2010
#
# who has the least apps and less than 103 goals
#
# which year was the most recent year los_angeles was the 2nd_venue
#
# which year was the latest year that sheffield was the 2nd_venue
#
# what is the amount of the most goals after 1999
#
# what is the amount of the most goals after 2003
#
# which state had the least number_of_candidates in 2003
#
# who has the least games played with an average below 30
#
# who has the most goals but less than 390 apps
#
# who has the least apps and less than 123 goals
#
# who has the most games played with an average above 30
#
# who has the least 100s with an average of 50
#
# who has the least innings with an average of 50
#
# what is the amount of the most goals after 2008
#
# who has the most goals but less than 422 apps
#
# who has the least runs with an average of 50
#
# who has the most free_throws with an average below 20
#
# when did the first to leave_office who was labour
#
# who has the least games played with an average below 50
#
# who has the most goals but less than 330 apps
#
# who has the least games played with an average of 20
#
# who has the least field_goals with an average below 50
#
# when did the last to leave_office who was conservatives
#
# who has the most matches with an average above 80
#
# who has the most matches with an average above 20
#
# who has the least field_goals with an average above 70
#
# who has the most points with an average above 50
#
# when was the first time sheffield was 3rd_venue
#
# which year was the latest year that tokyo was the 1st_venue
#
# who has the most 50s with an average below 30
#
# who has the least apps and greater than 197 goals
#
# who has the most 100s with an average below 20
#
# which state had the least number_of_candidates in 2013
#
# who has the least innings with an average above 80
#
# who has the most 50s with an average of 80
#
# who has the least apps and greater than 85 goals
#
# who has the least free_throws with an average below 80
#
# which year was the latest year that washington was the 1st_venue
#
# who has the least free_throws with an average above 30
#
# who has the least matches with an average below 80
#
# which year was the latest year that chicago was the 1st_venue
#
# who has the least field_goals with an average below 30
#
# who has the least 100s with an average below 20
#
# who is the goalkeeper with the most apps
#
# who has the most free_throws with an average below 80
#
# which year was the latest year that cambridge was the 2nd_venue
#
# who has the most matches with an average above 30
#
# when did the last to take_office who was liberal_democrats
#
# which year was the most recent year veracruz was the 2nd_venue
#
# when was the first time minneapolis was 2nd_venue
#
# who has the most matches with an average below 70
#
# which year was the latest year that indianapolis was the 1st_venue
#
# who has the most field_goals with an average of 20
#
# what is the amount of the most goals after 2009
#
# who has the most field_goals with an average above 20
#
# who has the least 50s with an average of 70
#
# what is the amount of the most goals after 2010
#
# who has the most points with an average of 70
#
# who has the most points with an average below 80
#
# what is the amount of the most goals before 2015
#
# who has the most free_throws with an average below 30
#
# what is the amount of the most goals after 2016
#
# who has the most goals but less than 151 apps
#
# what is the amount of the least goals after 2012
#
# when was the first time boston was 3rd_venue
#
# which state had the least number_of_candidates in 2014
#
# which year was the most recent year tokyo was the 2nd_venue
#
# who has the most innings with an average above 50
#
# who has the least matches with an average above 50
#
# which year was the latest year that guanajuato was the 2nd_venue
#
# who has the most innings with an average of 30
#
# who has the most games played with an average above 50
#
# who has the most 50s with an average of 20
#
# which year was the most recent year chicago was the 2nd_venue

# %% [markdown]
# ### Now we collect all different schema in a list for later use

# %%
schema_collect = []
with open('./rand.fi') as f_fi:
    for line in f_fi:
        if line in schema_collect:
            continue
        schema_collect.append(line)
    
for schema in schema_collect:
    print schema
# Out:
# Nation Rank Gold Silver Bronze Total
#
# Name Year_inducted Position Apps Goals
#
# Year 1st_Venue 2nd_Venue 3rd_Venue 4th_Venue 5th_Venue 6th_Venue
#
# Player Matches Innings Runs Average 100s 50s Games_Played Field_Goals Free_Throws Points
#
# Team County Wins Years_won Areas Prices
#
# Country Masters U.S._Open The_Open PGA Total
#
# Swara Position Short_name Notation Mnemonic
#
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# Discipline Amanda Bernie Javine_H Julia Michelle
#
# Nation Name Position League_Apps League_Goals FA_Cup_Apps FA_Cup_Goals Total_Apps Total_Goals
#
# Menteri_Besar Took_office Left_office Party

# %% [markdown]
# ### Next we do some data generation, the small goal is to double our current data size (8k~10k)
#
# As we previously did some work in the file ./data_prep/categorization.txt, we have several different sentences for a single length category. For each sentence structure, we first see whether it could applied to all or several schema, or just a single schema; then we tag each sentence, and for 'field' and 'value', we do data recombination for both query and logical forms; finally we add noise and replace synonyms in the queries to further complicate the sentence structrue.
#
# Let's start with the easiest length = 3:

# %%
import os,sys,inspect

currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir)

import tagger as tg

# %%
schema_collect[2] = "State Year_of_Election No._of_candidates No._of_elected Total_no._of_seats_in_Assembly \n"
schema_collect[7] = "Year 1st_Venue 2nd_Venue 3rd_Venue 4th_Venue 5th_Venue 6th_Venue \n"
schema_collect[3] = "Team Years_won County Wins Areas Prices \n"
schema_collect[4] = "Player Matches Innings Runs Average 100s 50s Games_Played Field_Goals Free_Throws Points \n"

schema_collect[6] = "Discipline Amanda Bernie Javine_H Julia Michelle \n"
schema_collect[8] = "Swara Position Short_name Notation Mnemonic \n"
schema_collect[7] = "Nation Name Position League_Apps League_Goals FA_Cup_Apps FA_Cup_Goals Total_Apps Total_Goals \n"
schema_collect[9] = "Year 1st_Venue 2nd_Venue 3rd_Venue 4th_Venue 5th_Venue 6th_Venue \n"

for schema in schema_collect:
    print schema
# Out:
# Nation Rank Gold Silver Bronze Total
#
# Name Year_inducted Position Apps Goals
#
# State Year_of_Election No._of_candidates No._of_elected Total_no._of_seats_in_Assembly
#
# Team Years_won County Wins Areas Prices
#
# Player Matches Innings Runs Average 100s 50s Games_Played Field_Goals Free_Throws Points
#
# Country Masters U.S._Open The_Open PGA Total
#
# Discipline Amanda Bernie Javine_H Julia Michelle
#
# Nation Name Position League_Apps League_Goals FA_Cup_Apps FA_Cup_Goals Total_Apps Total_Goals
#
# Swara Position Short_name Notation Mnemonic
#
# Year 1st_Venue 2nd_Venue 3rd_Venue 4th_Venue 5th_Venue 6th_Venue
#
# Menteri_Besar Took_office Left_office Party

# %% [markdown]
# ==== Conventions ====
# 1. "o" stands for "ordinal" values, refering to schema_collect[0:4]
# 2. "n" stands for "numerical" values, refering to schema_collect[4:8]
# 3. "s" stands for "string" values, refering to schema_collect[7:]

# %%
len3read = """which country has the most pga championships
which country had the most number of wins
who was the first nation
what is the name of the first nation on this chart
which country won the largest haul of bronze medals
what is the name of the swara that holds the first position
which country had the least bronze medals
who was the last de player
who scored the least on whitewater_kayak
which nation received the largest amount of gold medals
which state has the top no._of_elected amount
the team with the most gold medals
which nation was ranked last
the country that won the most medals was
who was the top scorer in innings
what is the top listed player
who is the top ranked nation
what is the largest matches amount""".split('\n')

# idx = 0
# for i in range(len(len3read)):
#     idx += 1
#     print "====== example %d ======" %idx
#     tagged2, field_corr, value_corr, newquery, newlogical = \
#             tg.sentTagging_value(query_len[7][i], schema_len[7][i], logic_category_len[7][i])
#     print logic_category_len[7][i]
#     print schema_len[7][i]
#     print query_len[7][i]
#     print tagged2
#     print field_corr
#     print value_corr 
#     print newquery
#     print newlogical
#     print '\n'

lo_template3_max = 'argmax <field>:0 <field>:1'
lo_template3_min = 'argmin <field>:0 <field>:1'

tagged2, field_corr, value_corr, newquery, _ = \
            tg.sentTagging_value(len3read[0], schema_collect[5])
print schema_collect[5]
print len3read[0]
print tagged2
print field_corr
print value_corr 
print newquery
# Out:
# ['<field>', 'Country']
# ['<field>', 'PGA']
# [(5, 1)]
# []
# Country Masters U.S._Open The_Open PGA Total
#
# which country has the most pga championships
# <nan> <field>:0 <nan> <nan> <nan> <field>:1 <nan>
# Country PGA
# <nan> <nan>
# which <field>:0 has the most <field>:1 championships

# %%
print len3read
# Out:
# ['which country has the most pga championships', 'which country had the most number of wins', 'who was the first nation', 'what is the name of the first nation on this chart', 'which country won the largest haul of bronze medals', 'what is the name of the swara that holds the first position', 'which country had the least bronze medals', 'who was the last de player', 'who scored the least on whitewater_kayak', 'which nation received the largest amount of gold medals', 'which state has the top no._of_elected amount', 'the team with the most gold medals', 'which nation was ranked last', 'the country that won the most medals was', 'who was the top scorer in innings', 'what is the top listed player', 'who is the top ranked nation', 'what is the largest matches amount']
