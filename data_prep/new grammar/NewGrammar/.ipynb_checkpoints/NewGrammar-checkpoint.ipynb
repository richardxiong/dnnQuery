# %% [markdown]
# ## Grammar Version 2.0
# Edit and use for generate the 2nd version grammar archive 0507

# %%
import numpy as np

def renew19(line):
    tokens = line.split()
    newtokens = [x for x in tokens[:-1]]
    newtokens[0] = tokens[16]
    newtokens[1:3] = ['A', 'as']
    newtokens[3:5] = tokens[4:6]
    newtokens[5:9] = tokens[0:4]
    newtokens[9:12] = ['and', 'B', 'as']
    #newtokens[12:14] = tokens[12:14]
    newtokens[14:] = tokens[8:12]
    
    if newtokens[0] == 'mean':
        newtokens[0] = 'avg'
    newline = ' '.join(newtokens)
    return newline

def renew15(line):
    tokens = line.split()
    newtokens = [x for x in tokens[:-1]]
    newtokens[0:3] = tokens[12:]
    newtokens[3:7] = tokens[8:12]
    newtokens[7] = 'as'
    newtokens[8:10] = tokens[4:6]
    newtokens[10:] = tokens[0:4]
    newline = ' '.join(newtokens)
    return newline

def renew14(line):
    tokens = line.split()
    newtokens = [x for x in tokens[:-1]]
    newtokens[0:2] = tokens[12:]
    newtokens[2:6] = tokens[8:12]
    newtokens[6] = 'as'
    newtokens[7:9] = tokens[4:6]
    newtokens[9:] = tokens[0:4]
    newline = ' '.join(newtokens)
    return newline

def renew13(line):
    tokens = line.split()
    newtokens = [x for x in tokens[:-1]]
    newtokens[0] = tokens[10]
    newtokens[1:3] = ['A', 'as']
    newtokens[3:6] = tokens[0:3]
    newtokens[6:9] = ['and','B', 'as']
    newtokens[9:] = tokens[5:8]
    newline = ' '.join(newtokens)
    return newline

def renew11(line):
    tokens = line.split()
    newtokens = [x for x in tokens]
    newtokens[0:3] = tokens[8:]
    newtokens[3:7] = tokens[0:4]
    newtokens[7] = 'and'
    newtokens[8:] = tokens[5:8]
    newline = ' '.join(newtokens)
    return newline

def renew10(line):
    tokens = line.split()
    newtokens = [x for x in tokens]
    newtokens[0:2] = tokens[8:]
    newtokens[2:6] = tokens[0:4]
    newtokens[6] = 'and'
    newtokens[7:] = tokens[5:8]
    newline = ' '.join(newtokens)
    return newline

def renew7(line):
    tokens = line.split()
    newtokens = [x for x in tokens]
    newtokens[0:3] = tokens[4:]
    newtokens[3:] = tokens[0:4]
    newline = ' '.join(newtokens)
    return newline

def renew6(line):
    tokens = line.split()
    newtokens = [x for x in tokens]
    newtokens[0:2] = tokens[4:]
    newtokens[2:] = tokens[0:4]
    
    if newtokens[0] == 'mean':
        newtokens[0] = 'avg'
    newline = ' '.join(newtokens)
    return newline

def renew5(line):
    tokens = line.split()
    newtokens = [x for x in tokens]
    newtokens[0] = 'count'
    newtokens[1:] = tokens[0:4]
    newline = ' '.join(newtokens)
    return newline

len_search = dict()
f2 = open('./rand_test2.lo','w')
with open('./rand_test.lo') as f:
    for line in f:
        tokens = line.split()
        length = len(tokens)
        if length not in len_search:
            len_search[length] = []
        len_search[length].append(line)
        if length == 19:
            newline = renew19(line)
            f2.write(newline+'\n')
        elif length == 15:
            newline = renew15(line)
            f2.write(newline+'\n')
        elif length == 14:
            newline = renew14(line)
            f2.write(newline+'\n')
        elif length == 13:
            newline = renew13(line)
            f2.write(newline+'\n')
        elif length == 11:
            newline = renew11(line)
            f2.write(newline+'\n')
        elif length == 10:
            newline = renew10(line)
            f2.write(newline+'\n')
        elif length == 7:
            newline = renew7(line)
            f2.write(newline+'\n')
        elif length == 6:
            newline = renew6(line)
            f2.write(newline+'\n')
        elif length == 5:
            newline = renew5(line)
            f2.write(newline+'\n')
        else:
            f2.write(line)
f2.close()

for key in len_search.keys():
    value = len_search[key]
    print 'length = %d, total examples: %d' %(key, len(value))
# Out:
# length = 3, total examples: 21
# length = 5, total examples: 13
# length = 6, total examples: 148
# length = 7, total examples: 78
# length = 10, total examples: 86
# length = 11, total examples: 65
# length = 13, total examples: 1
# length = 14, total examples: 1
# length = 15, total examples: 23
# length = 19, total examples: 75

# %% [markdown]
# ## Grammar Version 3.0
# Used for generate new version of grammar (shorter version for sum, diff, avg)

# %%
def renew19(line):
    ''' from 19 to 11
    '''
    tokens = line.split()
    # newly changed
    # 'sum {comp_field1} where {comp_field2} {comp} {comp_val} and where {comp_field2} {comp} {query2_comp_val} '
    newtokens = [x for x in tokens[:11]]
    newtokens[0] = tokens[16]
    newtokens[1] = tokens[5]
    newtokens[2:6] = tokens[0:4]
    newtokens[6] = 'and'
    newtokens[7] = 'where'
    #newtokens[12:14] = tokens[12:14]
    newtokens[8:11] = tokens[9:12]
    
    if newtokens[0] == 'mean':
        newtokens[0] = 'avg'
    newline = ' '.join(newtokens)
    return newline

def renew15(line, query):
    ''' case 1: nested type: from 15 to 11
        case 2: before/after: from 15 to 6
    '''
    tokens = line.split()
    words = query.split()
    if words[0] == 'of':
        # case 1
        newtokens = [x for x in tokens[:11]]
        newtokens[0] = 'select'
        newtokens[1] = tokens[13]
        newtokens[2] = tokens[12]
        newtokens[3] = tokens[14]
        newtokens[4:7] = tokens[8:11]
        newtokens[7:11] = tokens[0:4]
    else:
        # case 2
        newtokens = [x for x in tokens[:6]]
        newtokens[0] = 'select'
        newtokens[1] = tokens[13]
        if tokens[10] == 'greater':
            newtokens[2] = 'next'
        else:
            newtokens[2] = 'prev'    
        newtokens[3:6] = tokens[1:4]
    
    newline = ' '.join(newtokens)
    return newline

def renew14(line):
    ''' before/after type, from 14 to 6
        New grammar: select {field1} next/prev {field2} equal {value2}
    '''
    tokens = line.split()
    # newly change
    newtokens = [x for x in tokens[:6]]
    newtokens[0:2] = tokens[12:]
    if tokens[10] == 'greater':
        newtokens[2] = 'next'
    else:
        newtokens[2] = 'prev'    
    newtokens[3:6] = tokens[1:4]
    newline = ' '.join(newtokens)
    return newline

def renew13(line):
    ''' from 13 to 7
    '''
    tokens = line.split()
    # newly changed: diff {comp_field1}' arg {max_min} {arg1} 'and' arg {max_min} {arg1}
    newtokens = [x for x in tokens[:7]]
    newtokens[0] = tokens[10]
    newtokens[1] = tokens[1]
    newtokens[2] = tokens[0]
    newtokens[3] = tokens[2]
    newtokens[4] = 'and'
    newtokens[5] = tokens[5]
    newtokens[6] = tokens[7]
    newline = ' '.join(newtokens)
    return newline

def renew11(line):
    ''' from 11 to 12
    '''
    tokens = line.split()
    newtokens = [x for x in tokens]
    newtokens[0:3] = tokens[8:]
    newtokens[3:7] = tokens[0:4]
    newtokens[7] = 'and'
    newtokens[8:] = tokens[5:8]
    
    # newly added
    newtokens.insert(0, 'select')
    temp = newtokens[1]
    newtokens[1] = newtokens[2]
    newtokens[2] = temp
    newline = ' '.join(newtokens)
    return newline

def renew10(line):
    tokens = line.split()
    newtokens = [x for x in tokens]
    newtokens[0:2] = tokens[8:]
    newtokens[2:6] = tokens[0:4]
    newtokens[6] = 'and'
    newtokens[7:] = tokens[5:8]
    newline = ' '.join(newtokens)
    return newline

def renew7(line):
    ''' from 7 to 8
    '''
    tokens = line.split()
    newtokens = [x for x in tokens]
    newtokens[0:3] = tokens[4:]
    newtokens[3:] = tokens[0:4]
    
    # newly added
    newtokens.insert(0, 'select')
    temp = newtokens[1]
    newtokens[1] = newtokens[2]
    newtokens[2] = temp
    newline = ' '.join(newtokens)
    return newline

def renew6(line):
    tokens = line.split()
    newtokens = [x for x in tokens]
    newtokens[0:2] = tokens[4:]
    newtokens[2:] = tokens[0:4]
    
    if newtokens[0] == 'mean':
        newtokens[0] = 'avg'
    newline = ' '.join(newtokens)
    return newline

def renew5(line, schema):
    ''' from 5 to 6
    '''
    tokens = line.split()
    newtokens = [x for x in tokens]
    newtokens[0] = 'count'
    newtokens[1:] = tokens[0:4]
    
    # newly added
    fields = schema.split()
    newtokens.insert(1, fields[0])
    newline = ' '.join(newtokens)
    return newline

def renew3(line):
    ''' from 3 to 4
    '''
    tokens = line.split()
    newtokens = [x for x in tokens]
    newtokens.insert(0, 'select')
    temp = newtokens[1]
    newtokens[1] = newtokens[2]
    newtokens[2] = temp
    newline = ' '.join(newtokens)
    return newline

# %%
len_search = dict()
qu_search = dict()
schema_search = dict()
with open('./rand_train.lo') as f_lo:
    with open('../../../data/rand_train.qu') as f_qu:
        with open('../../../data/rand_train.fi') as f_fi:
            logic, query, schema = f_lo.readline(), f_qu.readline(), f_fi.readline()
            while logic and query:
                tokens = logic.split()
                length = len(tokens)
                if length not in len_search:
                    len_search[length] = []
                    schema_search[length] = []
                    qu_search[length] = []
                len_search[length].append(logic)
                qu_search[length].append(query)
                schema_search[length].append(schema)
                logic, query, schema = f_lo.readline(), f_qu.readline(), f_fi.readline()
for key in len_search.keys():
    value = len_search[key]
    print 'length = %d, total examples: %d' %(key, len(value))
    
count = 0
for line in len_search[15]:
    idx = len_search[15].index(line)
    print schema_search[15][idx]
    print qu_search[15][idx]
    print line
    newline = renew15(line, qu_search[15][idx])
    print newline
#     if len(newline.split()) == 11:
#         count += 1
# print count
# Out:
# length = 2, total examples: 1
# length = 3, total examples: 111
# length = 5, total examples: 99
# length = 6, total examples: 739
# length = 7, total examples: 446
# length = 10, total examples: 490
# length = 11, total examples: 351
# length = 13, total examples: 3
# length = 14, total examples: 6
# length = 15, total examples: 109
# length = 19, total examples: 445
# Swara Position Short_name Notation Mnemonic
#
# what swara is above shadja
#
# where Swara equal Shadja select Position as A where Position less A argmax Swara Position
#
# select Swara prev Swara equal Shadja
# Team County Wins Years_won Areas Prices
#
# which team was the previous winner before fingal_ravens in 2008
#
# where Team equal Fingal_Ravens select Years as A where Years less A argmax Team Year
#
# select Team prev Team equal Fingal_Ravens
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with larger number_of_seats_in_assembly than bihar which state has the greatest number_of_candidates
#
# where State equal Bihar select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly greater A argmax State No._of_candidates
#
# select State argmax No._of_candidates where Total_no._of_seats_in_Assembly greater where State equal Bihar
# Nation Rank Gold Silver Bronze Total
#
# the nation before england
#
# where Nation equal England select Rank as A where Rank less A argmax Nation Rank
#
# select Nation prev Nation equal England
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with larger number_of_seats_in_assembly than goa which state has the greatest number_of_candidates
#
# where State equal Goa select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly greater A argmax State No._of_candidates
#
# select State argmax No._of_candidates where Total_no._of_seats_in_Assembly greater where State equal Goa
# Nation Rank Gold Silver Bronze Total
#
# the nation before netherlands
#
# where Nation equal Netherlands select Rank as A where Rank less A argmax Nation Rank
#
# select Nation prev Nation equal Netherlands
# Team County Wins Years_won Areas Prices
#
# which team was the previous winner before maynooth in 2006
#
# where Team equal Maynooth select Years as A where Years less A argmax Team Year
#
# select Team prev Team equal Maynooth
# Team County Wins Years_won Areas Prices
#
# which team was the next winner after maynooth in 2009
#
# where Team equal Maynooth select Years as A where Years greater A argmin Team Year
#
# select Team next Team equal Maynooth
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with smaller number_of_seats_in_assembly than assam which state has the minimum number_of_candidates
#
# where State equal Assam select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly less A argmin State No._of_candidates
#
# select State argmin No._of_candidates where Total_no._of_seats_in_Assembly less where State equal Assam
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with larger number_of_seats_in_assembly than himachal_pradesh which state has the greatest number_of_candidates
#
# where State equal Himachal_Pradesh select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly greater A argmax State No._of_candidates
#
# select State argmax No._of_candidates where Total_no._of_seats_in_Assembly greater where State equal Himachal_Pradesh
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with smaller number_of_candidates than meghalaya, which has the maximum number_of_elected
#
# where State equal Meghalaya select No._of_candidates as A where No._of_candidates less A argmax State No._of_elected
#
# select State argmax No._of_elected where No._of_candidates less where State equal Meghalaya
# Nation Rank Gold Silver Bronze Total
#
# the nation after italy
#
# where Nation equal Italy select Rank as A where Rank less A argmin Nation Rank
#
# select Nation prev Nation equal Italy
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with smaller number_of_seats_in_assembly than chhattisgarh which state has the minimum number_of_candidates
#
# where State equal Chhattisgarh select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly less A argmin State No._of_candidates
#
# select State argmin No._of_candidates where Total_no._of_seats_in_Assembly less where State equal Chhattisgarh
# Nation Rank Gold Silver Bronze Total
#
# the nation before wales
#
# where Nation equal Wales select Rank as A where Rank less A argmax Nation Rank
#
# select Nation prev Nation equal Wales
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with larger number_of_seats_in_assembly than karnataka which state has the greatest number_of_candidates
#
# where State equal Karnataka select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly greater A argmax State No._of_candidates
#
# select State argmax No._of_candidates where Total_no._of_seats_in_Assembly greater where State equal Karnataka
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with smaller number_of_candidates than tamil_nadu, which has the maximum number_of_elected
#
# where State equal Tamil_Nadu select No._of_candidates as A where No._of_candidates less A argmax State No._of_elected
#
# select State argmax No._of_elected where No._of_candidates less where State equal Tamil_Nadu
# Nation Rank Gold Silver Bronze Total
#
# the nation before spain
#
# where Nation equal Spain select Rank as A where Rank less A argmax Nation Rank
#
# select Nation prev Nation equal Spain
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with larger number_of_seats_in_assembly than jammu_and_kashmir which state has the greatest number_of_candidates
#
# where State equal Jammu_and_Kashmir select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly greater A argmax State No._of_candidates
#
# select State argmax No._of_candidates where Total_no._of_seats_in_Assembly greater where State equal Jammu_and_Kashmir
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with smaller number_of_seats_in_assembly than gujarat which state has the minimum number_of_candidates
#
# where State equal Gujarat select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly less A argmin State No._of_candidates
#
# select State argmin No._of_candidates where Total_no._of_seats_in_Assembly less where State equal Gujarat
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with smaller number_of_seats_in_assembly than tripura which state has the minimum number_of_candidates
#
# where State equal Tripura select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly less A argmin State No._of_candidates
#
# select State argmin No._of_candidates where Total_no._of_seats_in_Assembly less where State equal Tripura
# Swara Position Short_name Notation Mnemonic
#
# what is the name of the swara that come before antara_gandhara
#
# where Swara equal Antara_Gandhara select Position as A where Position less A argmax Swara Position
#
# select Swara prev Swara equal Antara_Gandhara
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with smaller number_of_candidates than manipur, which has the maximum number_of_elected
#
# where State equal Manipur select No._of_candidates as A where No._of_candidates less A argmax State No._of_elected
#
# select State argmax No._of_elected where No._of_candidates less where State equal Manipur
# Nation Rank Gold Silver Bronze Total
#
# the nation before australia
#
# where Nation equal Australia select Rank as A where Rank less A argmax Nation Rank
#
# select Nation prev Nation equal Australia
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with smaller number_of_candidates than assam, which has the maximum number_of_elected
#
# where State equal Assam select No._of_candidates as A where No._of_candidates less A argmax State No._of_elected
#
# select State argmax No._of_elected where No._of_candidates less where State equal Assam
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with smaller number_of_candidates than uttarakhand, which has the maximum number_of_elected
#
# where State equal Uttarakhand select No._of_candidates as A where No._of_candidates less A argmax State No._of_elected
#
# select State argmax No._of_elected where No._of_candidates less where State equal Uttarakhand
# Nation Rank Gold Silver Bronze Total
#
# the team after japan
#
# where Nation equal Japan select Rank as A where Rank greater A argmin Nation Rank
#
# select Nation next Nation equal Japan
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with smaller number_of_candidates than bihar, which has the maximum number_of_elected
#
# where State equal Bihar select No._of_candidates as A where No._of_candidates less A argmax State No._of_elected
#
# select State argmax No._of_elected where No._of_candidates less where State equal Bihar
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with larger number_of_seats_in_assembly than chhattisgarh which state has the greatest number_of_candidates
#
# where State equal Chhattisgarh select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly greater A argmax State No._of_candidates
#
# select State argmax No._of_candidates where Total_no._of_seats_in_Assembly greater where State equal Chhattisgarh
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with smaller number_of_candidates than rajasthan, which has the maximum number_of_elected
#
# where State equal Rajasthan select No._of_candidates as A where No._of_candidates less A argmax State No._of_elected
#
# select State argmax No._of_elected where No._of_candidates less where State equal Rajasthan
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with larger number_of_seats_in_assembly than gujarat which state has the greatest number_of_candidates
#
# where State equal Gujarat select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly greater A argmax State No._of_candidates
#
# select State argmax No._of_candidates where Total_no._of_seats_in_Assembly greater where State equal Gujarat
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with smaller number_of_seats_in_assembly than manipur which state has the minimum number_of_candidates
#
# where State equal Manipur select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly less A argmin State No._of_candidates
#
# select State argmin No._of_candidates where Total_no._of_seats_in_Assembly less where State equal Manipur
# Swara Position Short_name Notation Mnemonic
#
# what is the name of the swara that come before shatshruti_dhaivata
#
# where Swara equal Shatshruti_Dhaivata select Position as A where Position less A argmax Swara Position
#
# select Swara prev Swara equal Shatshruti_Dhaivata
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with smaller number_of_seats_in_assembly than rajasthan which state has the minimum number_of_candidates
#
# where State equal Rajasthan select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly less A argmin State No._of_candidates
#
# select State argmin No._of_candidates where Total_no._of_seats_in_Assembly less where State equal Rajasthan
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with smaller number_of_candidates than mizoram, which has the maximum number_of_elected
#
# where State equal Mizoram select No._of_candidates as A where No._of_candidates less A argmax State No._of_elected
#
# select State argmax No._of_elected where No._of_candidates less where State equal Mizoram
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with larger number_of_seats_in_assembly than assam which state has the greatest number_of_candidates
#
# where State equal Assam select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly greater A argmax State No._of_candidates
#
# select State argmax No._of_candidates where Total_no._of_seats_in_Assembly greater where State equal Assam
# Nation Rank Gold Silver Bronze Total
#
# the nation after netherlands
#
# where Nation equal Netherlands select Rank as A where Rank less A argmin Nation Rank
#
# select Nation prev Nation equal Netherlands
# Team County Wins Years_won Areas Prices
#
# which team was the previous winner before wolfe_tones in 2008
#
# where Team equal Wolfe_Tones select Years as A where Years less A argmax Team Year
#
# select Team prev Team equal Wolfe_Tones
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with smaller number_of_seats_in_assembly than mizoram which state has the minimum number_of_candidates
#
# where State equal Mizoram select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly less A argmin State No._of_candidates
#
# select State argmin No._of_candidates where Total_no._of_seats_in_Assembly less where State equal Mizoram
# Nation Rank Gold Silver Bronze Total
#
# the nation after mexico
#
# where Nation equal Mexico select Rank as A where Rank less A argmin Nation Rank
#
# select Nation prev Nation equal Mexico
# Nation Rank Gold Silver Bronze Total
#
# the nation after wales
#
# where Nation equal Wales select Rank as A where Rank less A argmin Nation Rank
#
# select Nation prev Nation equal Wales
# Nation Rank Gold Silver Bronze Total
#
# the team before nepal
#
# where Nation equal Nepal select Rank as A where Rank less A argmax Nation Rank
#
# select Nation prev Nation equal Nepal
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with smaller number_of_candidates than madhya_pradesh, which has the maximum number_of_elected
#
# where State equal Madhya_Pradesh select No._of_candidates as A where No._of_candidates less A argmax State No._of_elected
#
# select State argmax No._of_elected where No._of_candidates less where State equal Madhya_Pradesh
# Swara Position Short_name Notation Mnemonic
#
# what is the name of the swara that come before panchama
#
# where Swara equal Panchama select Position as A where Position less A argmax Swara Position
#
# select Swara prev Swara equal Panchama
# Nation Rank Gold Silver Bronze Total
#
# the nation after england
#
# where Nation equal England select Rank as A where Rank less A argmin Nation Rank
#
# select Nation prev Nation equal England
# Nation Rank Gold Silver Bronze Total
#
# the team before algeria
#
# where Nation equal Algeria select Rank as A where Rank less A argmax Nation Rank
#
# select Nation prev Nation equal Algeria
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with larger number_of_seats_in_assembly than manipur which state has the greatest number_of_candidates
#
# where State equal Manipur select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly greater A argmax State No._of_candidates
#
# select State argmax No._of_candidates where Total_no._of_seats_in_Assembly greater where State equal Manipur
# Swara Position Short_name Notation Mnemonic
#
# what is the name of the swara that come after panchama
#
# where Swara equal Panchama select Position as A where Position greater A argmin Swara Position
#
# select Swara next Swara equal Panchama
# Swara Position Short_name Notation Mnemonic
#
# what is the name of the swara that come after panchama
#
# where Swara equal Panchama select Position as A where Position greater A argmin Swara Position
#
# select Swara next Swara equal Panchama
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with larger number_of_seats_in_assembly than delhi which state has the greatest number_of_candidates
#
# where State equal Delhi select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly greater A argmax State No._of_candidates
#
# select State argmax No._of_candidates where Total_no._of_seats_in_Assembly greater where State equal Delhi
# Swara Position Short_name Notation Mnemonic
#
# what swara is below shadja
#
# where Swara equal Shadja select Position as A where Position greater A argmin Swara Position
#
# select Swara next Swara equal Shadja
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with smaller number_of_candidates than west_bengal, which has the maximum number_of_elected
#
# where State equal West_Bengal select No._of_candidates as A where No._of_candidates less A argmax State No._of_elected
#
# select State argmax No._of_elected where No._of_candidates less where State equal West_Bengal
# Nation Rank Gold Silver Bronze Total
#
# the nation before romania
#
# where Nation equal Romania select Rank as A where Rank less A argmax Nation Rank
#
# select Nation prev Nation equal Romania
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with larger number_of_seats_in_assembly than meghalaya which state has the greatest number_of_candidates
#
# where State equal Meghalaya select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly greater A argmax State No._of_candidates
#
# select State argmax No._of_candidates where Total_no._of_seats_in_Assembly greater where State equal Meghalaya
# Team County Wins Years_won Areas Prices
#
# which team was the previous winner before fingal_ravens in 2008
#
# where Team equal Fingal_Ravens select Years as A where Years less A argmax Team Year
#
# select Team prev Team equal Fingal_Ravens
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with larger number_of_seats_in_assembly than mizoram which state has the greatest number_of_candidates
#
# where State equal Mizoram select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly greater A argmax State No._of_candidates
#
# select State argmax No._of_candidates where Total_no._of_seats_in_Assembly greater where State equal Mizoram
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with smaller number_of_candidates than kerala, which has the maximum number_of_elected
#
# where State equal Kerala select No._of_candidates as A where No._of_candidates less A argmax State No._of_elected
#
# select State argmax No._of_elected where No._of_candidates less where State equal Kerala
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with smaller number_of_candidates than gujarat, which has the maximum number_of_elected
#
# where State equal Gujarat select No._of_candidates as A where No._of_candidates less A argmax State No._of_elected
#
# select State argmax No._of_elected where No._of_candidates less where State equal Gujarat
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with larger number_of_seats_in_assembly than rajasthan which state has the greatest number_of_candidates
#
# where State equal Rajasthan select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly greater A argmax State No._of_candidates
#
# select State argmax No._of_candidates where Total_no._of_seats_in_Assembly greater where State equal Rajasthan
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with smaller number_of_seats_in_assembly than uttarakhand which state has the minimum number_of_candidates
#
# where State equal Uttarakhand select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly less A argmin State No._of_candidates
#
# select State argmin No._of_candidates where Total_no._of_seats_in_Assembly less where State equal Uttarakhand
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with smaller number_of_seats_in_assembly than maharashtra which state has the minimum number_of_candidates
#
# where State equal Maharashtra select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly less A argmin State No._of_candidates
#
# select State argmin No._of_candidates where Total_no._of_seats_in_Assembly less where State equal Maharashtra
# Nation Rank Gold Silver Bronze Total
#
# the nation after spain
#
# where Nation equal Spain select Rank as A where Rank less A argmin Nation Rank
#
# select Nation prev Nation equal Spain
# Team County Wins Years_won Areas Prices
#
# which team was the previous winner before ballyroan_abbey in 2008
#
# where Team equal Ballyroan_Abbey select Years as A where Years less A argmax Team Year
#
# select Team prev Team equal Ballyroan_Abbey
# Team County Wins Years_won Areas Prices
#
# which team was the previous winner before fingal_ravens in 2008
#
# where Team equal Fingal_Ravens select Years as A where Years less A argmax Team Year
#
# select Team prev Team equal Fingal_Ravens
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with smaller number_of_candidates than maharashtra, which has the maximum number_of_elected
#
# where State equal Maharashtra select No._of_candidates as A where No._of_candidates less A argmax State No._of_elected
#
# select State argmax No._of_elected where No._of_candidates less where State equal Maharashtra
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with smaller number_of_candidates than tripura, which has the maximum number_of_elected
#
# where State equal Tripura select No._of_candidates as A where No._of_candidates less A argmax State No._of_elected
#
# select State argmax No._of_elected where No._of_candidates less where State equal Tripura
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with larger number_of_seats_in_assembly than uttarakhand which state has the greatest number_of_candidates
#
# where State equal Uttarakhand select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly greater A argmax State No._of_candidates
#
# select State argmax No._of_candidates where Total_no._of_seats_in_Assembly greater where State equal Uttarakhand
# Team County Wins Years_won Areas Prices
#
# which team was the previous winner before ballyroan_abbey in 2008
#
# where Team equal Ballyroan_Abbey select Years as A where Years less A argmax Team Year
#
# select Team prev Team equal Ballyroan_Abbey
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with smaller number_of_seats_in_assembly than karnataka which state has the minimum number_of_candidates
#
# where State equal Karnataka select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly less A argmin State No._of_candidates
#
# select State argmin No._of_candidates where Total_no._of_seats_in_Assembly less where State equal Karnataka
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with smaller number_of_candidates than chhattisgarh, which has the maximum number_of_elected
#
# where State equal Chhattisgarh select No._of_candidates as A where No._of_candidates less A argmax State No._of_elected
#
# select State argmax No._of_elected where No._of_candidates less where State equal Chhattisgarh
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with smaller number_of_seats_in_assembly than delhi which state has the minimum number_of_candidates
#
# where State equal Delhi select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly less A argmin State No._of_candidates
#
# select State argmin No._of_candidates where Total_no._of_seats_in_Assembly less where State equal Delhi
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with larger number_of_seats_in_assembly than tripura which state has the greatest number_of_candidates
#
# where State equal Tripura select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly greater A argmax State No._of_candidates
#
# select State argmax No._of_candidates where Total_no._of_seats_in_Assembly greater where State equal Tripura
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with larger number_of_seats_in_assembly than punjab, which state has the greatest number_of_candidates
#
# where State equal Punjab select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly greater A argmax State No._of_candidates
#
# select State argmax No._of_candidates where Total_no._of_seats_in_Assembly greater where State equal Punjab
# Team County Wins Years_won Areas Prices
#
# which team was the next winner after maynooth in 2009
#
# where Team equal Maynooth select Years as A where Years greater A argmin Team Year
#
# select Team next Team equal Maynooth
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with smaller number_of_candidates than jammu_and_kashmir, which has the maximum number_of_elected
#
# where State equal Jammu_and_Kashmir select No._of_candidates as A where No._of_candidates less A argmax State No._of_elected
#
# select State argmax No._of_elected where No._of_candidates less where State equal Jammu_and_Kashmir
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with smaller number_of_seats_in_assembly than himachal_pradesh which state has the minimum number_of_candidates
#
# where State equal Himachal_Pradesh select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly less A argmin State No._of_candidates
#
# select State argmin No._of_candidates where Total_no._of_seats_in_Assembly less where State equal Himachal_Pradesh
# Swara Position Short_name Notation Mnemonic
#
# what swara is below antara_gandhara
#
# where Swara equal Antara_Gandhara select Position as A where Position greater A argmin Swara Position
#
# select Swara next Swara equal Antara_Gandhara
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with smaller number_of_seats_in_assembly than puducherry which state has the minimum number_of_candidates
#
# where State equal Puducherry select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly less A argmin State No._of_candidates
#
# select State argmin No._of_candidates where Total_no._of_seats_in_Assembly less where State equal Puducherry
# Nation Rank Gold Silver Bronze Total
#
# the team after nepal
#
# where Nation equal Nepal select Rank as A where Rank greater A argmin Nation Rank
#
# select Nation next Nation equal Nepal
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with larger number_of_seats_in_assembly than uttar_pradesh which state has the greatest number_of_candidates
#
# where State equal Uttar_Pradesh select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly greater A argmax State No._of_candidates
#
# select State argmax No._of_candidates where Total_no._of_seats_in_Assembly greater where State equal Uttar_Pradesh
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with larger number_of_seats_in_assembly than puducherry which state has the greatest number_of_candidates
#
# where State equal Puducherry select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly greater A argmax State No._of_candidates
#
# select State argmax No._of_candidates where Total_no._of_seats_in_Assembly greater where State equal Puducherry
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with smaller number_of_candidates than odisha, which has the maximum number_of_elected
#
# where State equal Odisha select No._of_candidates as A where No._of_candidates less A argmax State No._of_elected
#
# select State argmax No._of_elected where No._of_candidates less where State equal Odisha
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with larger number_of_seats_in_assembly than tamil_nadu which state has the greatest number_of_candidates
#
# where State equal Tamil_Nadu select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly greater A argmax State No._of_candidates
#
# select State argmax No._of_candidates where Total_no._of_seats_in_Assembly greater where State equal Tamil_Nadu
# Nation Rank Gold Silver Bronze Total
#
# the team before china
#
# where Nation equal China select Rank as A where Rank less A argmax Nation Rank
#
# select Nation prev Nation equal China
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with larger number_of_seats_in_assembly than madhya_pradesh which state has the greatest number_of_candidates
#
# where State equal Madhya_Pradesh select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly greater A argmax State No._of_candidates
#
# select State argmax No._of_candidates where Total_no._of_seats_in_Assembly greater where State equal Madhya_Pradesh
# Swara Position Short_name Notation Mnemonic
#
# what is the name of the swara that come after shatshruti_dhaivata
#
# where Swara equal Shatshruti_Dhaivata select Position as A where Position greater A argmin Swara Position
#
# select Swara next Swara equal Shatshruti_Dhaivata
# Nation Rank Gold Silver Bronze Total
#
# the team after france
#
# where Nation equal France select Rank as A where Rank greater A argmin Nation Rank
#
# select Nation next Nation equal France
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with smaller number_of_candidates than goa, which has the maximum number_of_elected
#
# where State equal Goa select No._of_candidates as A where No._of_candidates less A argmax State No._of_elected
#
# select State argmax No._of_elected where No._of_candidates less where State equal Goa
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with larger number_of_seats_in_assembly than west_bengal which state has the greatest number_of_candidates
#
# where State equal West_Bengal select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly greater A argmax State No._of_candidates
#
# select State argmax No._of_candidates where Total_no._of_seats_in_Assembly greater where State equal West_Bengal
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with smaller number_of_candidates than andhra_pradesh, which has the maximum number_of_elected
#
# where State equal Andhra_Pradesh select No._of_candidates as A where No._of_candidates less A argmax State No._of_elected
#
# select State argmax No._of_elected where No._of_candidates less where State equal Andhra_Pradesh
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with larger number_of_seats_in_assembly than odisha which state has the greatest number_of_candidates
#
# where State equal Odisha select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly greater A argmax State No._of_candidates
#
# select State argmax No._of_candidates where Total_no._of_seats_in_Assembly greater where State equal Odisha
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with larger number_of_seats_in_assembly than punjab, which state has the greatest number_of_candidates
#
# where State equal Punjab select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly greater A argmax State No._of_candidates
#
# select State argmax No._of_candidates where Total_no._of_seats_in_Assembly greater where State equal Punjab
# Nation Rank Gold Silver Bronze Total
#
# the team before france
#
# where Nation equal France select Rank as A where Rank less A argmax Nation Rank
#
# select Nation prev Nation equal France
# Team County Wins Years_won Areas Prices
#
# which team was the next winner after wolfe_tones in 2009
#
# where Team equal Wolfe_Tones select Years as A where Years greater A argmin Team Year
#
# select Team next Team equal Wolfe_Tones
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with smaller number_of_seats_in_assembly than west_bengal which state has the minimum number_of_candidates
#
# where State equal West_Bengal select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly less A argmin State No._of_candidates
#
# select State argmin No._of_candidates where Total_no._of_seats_in_Assembly less where State equal West_Bengal
# Swara Position Short_name Notation Mnemonic
#
# what swara is below shadja
#
# where Swara equal Shadja select Position as A where Position greater A argmin Swara Position
#
# select Swara next Swara equal Shadja
# Team County Wins Years_won Areas Prices
#
# which team was the next winner after fingal_ravens in 2009
#
# where Team equal Fingal_Ravens select Years as A where Years greater A argmin Team Year
#
# select Team next Team equal Fingal_Ravens
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with smaller number_of_seats_in_assembly than bihar which state has the minimum number_of_candidates
#
# where State equal Bihar select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly less A argmin State No._of_candidates
#
# select State argmin No._of_candidates where Total_no._of_seats_in_Assembly less where State equal Bihar
# Nation Rank Gold Silver Bronze Total
#
# the nation after romania
#
# where Nation equal Romania select Rank as A where Rank less A argmin Nation Rank
#
# select Nation prev Nation equal Romania
# Nation Rank Gold Silver Bronze Total
#
# the nation before mexico
#
# where Nation equal Mexico select Rank as A where Rank less A argmax Nation Rank
#
# select Nation prev Nation equal Mexico
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with larger number_of_seats_in_assembly than haryana which state has the greatest number_of_candidates
#
# where State equal Haryana select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly greater A argmax State No._of_candidates
#
# select State argmax No._of_candidates where Total_no._of_seats_in_Assembly greater where State equal Haryana
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with smaller number_of_candidates than punjab, which has the maximum number_of_elected
#
# where State equal Punjab select No._of_candidates as A where No._of_candidates less A argmax State No._of_elected
#
# select State argmax No._of_elected where No._of_candidates less where State equal Punjab
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with smaller number_of_seats_in_assembly than uttar_pradesh which state has the minimum number_of_candidates
#
# where State equal Uttar_Pradesh select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly less A argmin State No._of_candidates
#
# select State argmin No._of_candidates where Total_no._of_seats_in_Assembly less where State equal Uttar_Pradesh
# Nation Rank Gold Silver Bronze Total
#
# the nation after brazil
#
# where Nation equal Brazil select Rank as A where Rank less A argmin Nation Rank
#
# select Nation prev Nation equal Brazil
# Swara Position Short_name Notation Mnemonic
#
# what is the name of the swara that come after shatshruti_dhaivata
#
# where Swara equal Shatshruti_Dhaivata select Position as A where Position greater A argmin Swara Position
#
# select Swara next Swara equal Shatshruti_Dhaivata
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with smaller number_of_candidates than karnataka, which has the maximum number_of_elected
#
# where State equal Karnataka select No._of_candidates as A where No._of_candidates less A argmax State No._of_elected
#
# select State argmax No._of_elected where No._of_candidates less where State equal Karnataka
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with larger number_of_seats_in_assembly than andhra_pradesh which state has the greatest number_of_candidates
#
# where State equal Andhra_Pradesh select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly greater A argmax State No._of_candidates
#
# select State argmax No._of_candidates where Total_no._of_seats_in_Assembly greater where State equal Andhra_Pradesh
# Team County Wins Years_won Areas Prices
#
# which team was the previous winner before ballyroan_abbey in 2008
#
# where Team equal Ballyroan_Abbey select Years as A where Years less A argmax Team Year
#
# select Team prev Team equal Ballyroan_Abbey
# State No._of_candidates No._of_elected Total_no._of_seats_in_Assembly Year_of_Election
#
# of all the states with smaller number_of_seats_in_assembly than punjab which state has the minimum number_of_candidates
#
# where State equal Punjab select Total_no._of_seats_in_Assembly as A where Total_no._of_seats_in_Assembly less A argmin State No._of_candidates
#
# select State argmin No._of_candidates where Total_no._of_seats_in_Assembly less where State equal Punjab
# Team County Wins Years_won Areas Prices
#
# which team was the next winner after fingal_ravens in 2009
#
# where Team equal Fingal_Ravens select Years as A where Years greater A argmin Team Year
#
# select Team next Team equal Fingal_Ravens

# %%
lo_search = dict()
f2 = open('./rand_test2.lo','w')
with open('./rand_test.lo') as f:
    for line in f:
        tokens = line.split()
        length = len(tokens)
        if length not in lo_search:
            lo_search[length] = []
        lo_search[length].append(line)
        if length == 19:
            newline = renew19(line)
            f2.write(newline+'\n')
        elif length == 15:
            newline = renew15(line)
            f2.write(newline+'\n')
        elif length == 14:
            newline = renew14(line)
            f2.write(newline+'\n')
        elif length == 13:
            newline = renew13(line)
            f2.write(newline+'\n')
        elif length == 11:
            newline = renew11(line)
            f2.write(newline+'\n')
        elif length == 10:
            newline = renew10(line)
            f2.write(newline+'\n')
        elif length == 7:
            newline = renew7(line)
            f2.write(newline+'\n')
        elif length == 6:
            newline = renew6(line)
            f2.write(newline+'\n')
        elif length == 5:
            newline = renew5(line)
            f2.write(newline+'\n')
        elif length == 3:
            newline = renew3(line)
            f2.write(newline+'\n')
        else:
            f2.write(line)
f2.close()

for key in lo_search.keys():
    value = lo_search[key]
    print 'length = %d, total examples: %d' %(key, len(value))
